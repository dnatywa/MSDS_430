# %% [markdown]
# # MSDS 430 Module 1 Python Assignment

# %% [markdown]
# #### In this assignment you will complete the following exercises and submit your notebook (ipynb file) to Canvas. Your file should include all output, i.e. run each cell and save your file before submitting.

# %% [markdown]
# <font color=green> The purpose of this assignment is to give you an introduction to the different Python environments that we will be working with throughout. We'll primarily be using Jupyter Notebooks, but you will see from the videos each week that other environments are used as the narrator explains topics. So it's important to understand a little bit about the differences between them. You are encouraged to do more with each of these environments on your own. </font>

# %% [markdown]
# Problem 1 (2 pts.): Print the string 'This is my first Python assignment.'

# %%
print("This is my first Python assignment")
# Out:
# This is my first Python assignment

# %% [markdown]
# Problem 2 (2 pts.): Insert two cells below this. One should be a code cell. In the code cell write code that prints 'Hello, World!' The other should be a markdown cell. Type anything you'd like in the markdown cell.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# I am excited to be learning Python!

# %% [markdown]
# Problem 3 (2 pts.): From the interactive interpreter on your computer, find the product of any two numbers. Take a screenshot and insert your screenshot in the cell below.

# %% [markdown]
# ![Terminal%20Screen%20Shot.png](attachment:Terminal%20Screen%20Shot.png)

# %% [markdown]
# Problem 4 (2 pts.): Open Anaconda on your computer and take a screenshot. Insert your screenshot in the cell below.

# %% [markdown]
# ![Anaconda%20Screen%20Shot.png](attachment:Anaconda%20Screen%20Shot.png)

# %% [markdown]
# Problem 5 (2 pts.): From Anaconda, open Spyder. In the iPython console (lower right), find the sum of any two numbers. Take a screenshot and insert your screenshot in the cell below.

# %% [markdown]
# ![Spyder%20Screen%20Shot%20.png](attachment:Spyder%20Screen%20Shot%20.png)
